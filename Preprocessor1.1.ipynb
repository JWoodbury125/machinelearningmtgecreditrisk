# %%
### Libraries ###

import pandas as pd
import numpy as np
import matplotlib as mlt
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML

# %% [markdown]
# # Loading data

# %%
my_data = pd.read_csv("/Users/ujwal/Documents/Project2/Data/2015_PUDB_EXPORT_123115.csv", header=0)

# %%
data = pd.read_excel("/Users/Ujwal/Documents/Project2/Data/2017_PUDB_EXPORT.xlsx")

# %%
my_data.shape
# Out:
# (47480, 87)

# %% [markdown]
# # Loading state Data

# %%
state_df = pd.read_excel("/Users/ujwal/Downloads/State_Codes.xlsx", header=0)

# %%
#Prepare to merge

state_df = state_df.rename(columns = {'FIPS':'FIPSStateCode'})

# %% [markdown]
# # Merging the data on FIPS State code

# %%
firsttrydf = my_data.merge(state_df, how='left')

# %%
firsttrydf.shape
# Out:
# (47480, 89)

# %%
firsttrydf = firsttrydf.rename(columns={'Name':'PropertyLocation'})

# %%
firsttrydf.columns
# Out:
# Index(['Year', 'AssignedID', 'FHLBank', 'FIPSStateCode', 'FIPSCountyCode',
#        'MSA', 'FeatureID', 'Tract', 'MinPer', 'TraMedY', 'LocMedY', 'Tractrat',
#        'Income', 'CurAreY', 'IncRat', 'UPB', 'LTV', 'MortDate', 'AcqDate',
#        'Purpose', 'Coop', 'Product', 'FedGuar', 'Term', 'AmorTerm', 'SellType',
#        'NumBor', 'First', 'CICA', 'BoRace', 'CoRace', 'BoGender', 'CoGender',
#        'BoAge', 'CoAge', 'Occup', 'NumUnits', 'Bed1', 'Bed2', 'Bed3', 'Bed4',
#        'Aff1', 'Aff2', 'Aff3', 'Aff4', 'Rent1', 'Rent2', 'Rent3', 'Rent4',
#        'RentUt1', 'RentUt2', 'RentUt3', 'RentUt4', 'Geog', 'Rate', 'Amount',
#        'Front', 'Back', 'BoCreditScor', 'CoCreditScor', 'PMI', 'Self',
#        'PropType', 'ArmIndex', 'ArmMarg', 'PrepayP', 'BoEth', 'Race2', 'Race3',
#        'Race4', 'Race5', 'CoEth', 'CoRace2', 'CoRace3', 'CoRace4', 'CoRace5',
#        'HOEPA', 'LienStatus', 'SpcHsgGoals', 'FedFinStbltyPlan', 'AcqTyp',
#        'GSEREO', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85',
#        'Unnamed: 86', 'PropertyLocation', 'Postal Code'],
#       dtype='object')

# %%
#Converting Amorterm in years to calculate PMT
for i in firsttrydf.index:
    firsttrydf.at[i,'AmorTerm'] = firsttrydf.at[i,'AmorTerm'] /12

# %%
# Taking first row to find pmt for a single application

np.pmt(rate=firsttrydf.at[0,'Rate'], fv=0, nper=firsttrydf.at[0,'AmorTerm'], pv=firsttrydf.at[0,'Amount'])
# Out:
# -18107.607252118236

# %%
# Creating a dummy PMT column

firsttrydf['PMT'] = "Nan"

# %%
#Applyting pmt function to the entire dataFrame

for i in firsttrydf.index:
    firsttrydf.at[i,'PMT'] = np.pmt(rate=firsttrydf.at[i,'Rate'], fv=0, nper=firsttrydf.at[i,'AmorTerm'], pv=firsttrydf.at[i,'Amount'])

# %% [markdown]
# # Filtering unwanted columns

# %%
interested_col_list = ['Year', 'AssignedID', 'FHLBank', 'FIPSStateCode', 'FIPSCountyCode',
       'Income', 'CurAreY', 'IncRat', 'UPB', 'LTV', 'MortDate', 'AcqDate',
       'Purpose', 'Coop', 'Product', 'FedGuar', 'AmorTerm', 'SellType',
       'NumBor', 'First', 'BoAge', 'CoAge', 'Occup', 'Rate', 'Amount',
       'Front', 'Back', 'BoCreditScor', 'CoCreditScor', 'PMI', 'PropertyLocation', 'PMT']

# %%
# Dropping unwanted columns on 2017 data [Chaitanya's Analysis]
data_corr = data.drop(['Year','Assigned ID','BoEth', 'Race2', 'Race3', 'Race4', 'Race5','CoEth', 'Corace2', 'Corace3', 'Corace4', 'Corace5','Rent1', 'Rent2', 'Rent3', 'Rent4',
       'RentUt1', 'RentUt2', 'RentUt3', 'RentUt4'], axis=1)

# %%
filtered_col_df = firsttrydf[interested_col_list]

# %%
data3 = filtered_col_df.head(100)
display(HTML(data3.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>AssignedID</th>
#       <th>FHLBank</th>
#       <th>FIPSStateCode</th>
#       <th>FIPSCountyCode</th>
#       <th>Income</th>
#       <th>CurAreY</th>
#       <th>IncRat</th>
#       <th>UPB</th>
#       <th>LTV</th>
#       <th>MortDate</th>
#       <th>AcqDate</th>
#       <th>Purpose</th>
#       <th>Coop</th>
#       <th>Product</th>
#       <th>FedGuar</th>
#       <th>AmorTerm</th>
#       <th>SellType</th>
#       <th>NumBor</th>
#       <th>First</th>
#       <th>BoAge</th>
#       <th>CoAge</th>
#       <th>Occup</th>
#       <th>Rate</th>
#       <th>Amount</th>
#       <th>Front</th>
#       <th>Back</th>
#       <th>BoCreditScor</th>
#       <th>CoCreditScor</th>
#       <th>PMI</th>
#       <th>PropertyLocation</th>
#       <th>PMT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2015</td>
#       <td>1997542</td>
#       <td>Atlanta</td>
#       <td>51</td>
#       <td>69</td>
#       <td>110904</td>
#       <td>65300</td>
#       <td>1.6984</td>
#       <td>334244</td>
#       <td>1.00</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>44</td>
#       <td>98</td>
#       <td>1</td>
#       <td>0.0338</td>
#       <td>338100</td>
#       <td>0.1923</td>
#       <td>0.4458</td>
#       <td>4</td>
#       <td>9</td>
#       <td>0.0</td>
#       <td>Virginia</td>
#       <td>-18107.6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2015</td>
#       <td>1997543</td>
#       <td>Atlanta</td>
#       <td>18</td>
#       <td>39</td>
#       <td>126984</td>
#       <td>51800</td>
#       <td>2.4514</td>
#       <td>126790</td>
#       <td>0.59</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>54</td>
#       <td>54</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>139500</td>
#       <td>0.0831</td>
#       <td>0.1253</td>
#       <td>5</td>
#       <td>5</td>
#       <td>0.0</td>
#       <td>Indiana</td>
#       <td>-7584.8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2015</td>
#       <td>1997544</td>
#       <td>Atlanta</td>
#       <td>13</td>
#       <td>245</td>
#       <td>72972</td>
#       <td>57900</td>
#       <td>1.2603</td>
#       <td>173761</td>
#       <td>0.65</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>66</td>
#       <td>64</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>176000</td>
#       <td>0.1951</td>
#       <td>0.2960</td>
#       <td>3</td>
#       <td>4</td>
#       <td>0.0</td>
#       <td>Georgia</td>
#       <td>-9569.35</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2015</td>
#       <td>1997545</td>
#       <td>Atlanta</td>
#       <td>12</td>
#       <td>9</td>
#       <td>88176</td>
#       <td>58600</td>
#       <td>1.5047</td>
#       <td>103961</td>
#       <td>0.97</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>79</td>
#       <td>77</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>105300</td>
#       <td>0.0817</td>
#       <td>0.1741</td>
#       <td>5</td>
#       <td>5</td>
#       <td>0.0</td>
#       <td>Florida</td>
#       <td>-5725.3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2015</td>
#       <td>1997546</td>
#       <td>Atlanta</td>
#       <td>32</td>
#       <td>3</td>
#       <td>101424</td>
#       <td>64300</td>
#       <td>1.5774</td>
#       <td>411696</td>
#       <td>0.84</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>65</td>
#       <td>54</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>417000</td>
#       <td>0.2706</td>
#       <td>0.4892</td>
#       <td>5</td>
#       <td>5</td>
#       <td>0.0</td>
#       <td>Nevada</td>
#       <td>-22672.8</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2015</td>
#       <td>1997547</td>
#       <td>Atlanta</td>
#       <td>24</td>
#       <td>17</td>
#       <td>54408</td>
#       <td>105700</td>
#       <td>0.5147</td>
#       <td>260840</td>
#       <td>1.03</td>
#       <td>2014</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>28</td>
#       <td>28</td>
#       <td>1</td>
#       <td>0.0363</td>
#       <td>264550</td>
#       <td>0.3759</td>
#       <td>0.3882</td>
#       <td>3</td>
#       <td>4</td>
#       <td>0.0</td>
#       <td>Maryland</td>
#       <td>-14619.2</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2015</td>
#       <td>1997548</td>
#       <td>Atlanta</td>
#       <td>12</td>
#       <td>109</td>
#       <td>191724</td>
#       <td>67300</td>
#       <td>2.8488</td>
#       <td>291248</td>
#       <td>1.00</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>57</td>
#       <td>57</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>295000</td>
#       <td>0.1235</td>
#       <td>0.4569</td>
#       <td>5</td>
#       <td>5</td>
#       <td>0.0</td>
#       <td>Florida</td>
#       <td>-16039.5</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2015</td>
#       <td>1997549</td>
#       <td>Atlanta</td>
#       <td>51</td>
#       <td>510</td>
#       <td>82500</td>
#       <td>105700</td>
#       <td>0.7805</td>
#       <td>265664</td>
#       <td>1.03</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>32</td>
#       <td>24</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>268650</td>
#       <td>0.2739</td>
#       <td>0.4011</td>
#       <td>5</td>
#       <td>4</td>
#       <td>0.0</td>
#       <td>Virginia</td>
#       <td>-14606.9</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2015</td>
#       <td>1997550</td>
#       <td>Atlanta</td>
#       <td>36</td>
#       <td>11</td>
#       <td>62076</td>
#       <td>56900</td>
#       <td>1.0910</td>
#       <td>152826</td>
#       <td>1.00</td>
#       <td>2014</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>65</td>
#       <td>50</td>
#       <td>1</td>
#       <td>0.0363</td>
#       <td>155000</td>
#       <td>0.2015</td>
#       <td>0.3225</td>
#       <td>5</td>
#       <td>5</td>
#       <td>0.0</td>
#       <td>New York</td>
#       <td>-8565.38</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2015</td>
#       <td>1997551</td>
#       <td>Atlanta</td>
#       <td>24</td>
#       <td>25</td>
#       <td>159096</td>
#       <td>85600</td>
#       <td>1.8586</td>
#       <td>343473</td>
#       <td>0.90</td>
#       <td>2014</td>
#       <td>2015</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>48</td>
#       <td>48</td>
#       <td>1</td>
#       <td>0.0388</td>
#       <td>348800</td>
#       <td>0.1750</td>
#       <td>0.2976</td>
#       <td>5</td>
#       <td>5</td>
#       <td>0.0</td>
#       <td>Maryland</td>
#       <td>-19878.3</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2015</td>
#       <td>1997552</td>
#       <td>Atlanta</td>
#       <td>13</td>
#       <td>113</td>
#       <td>64320</td>
#       <td>69300</td>
#       <td>0.9281</td>
#       <td>217456</td>
#       <td>1.00</td>
#       <td>2015</td>
#       <td>2015</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>30</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>75</td>
#       <td>76</td>
#       <td>1</td>
#       <td>0.0350</td>
#       <td>219900</td

# %%
#Converting negative numpy output to positive

print(abs(filtered_col_df.at[0,'PMT']))
# Out:
# 18107.607252118236

# %%
for i in filtered_col_df.index:
    filtered_col_df.at[i,'PMT'] = abs(filtered_col_df.at[i,'PMT'])

# %% [markdown]
# # Finding co-relations on the filtered data

# %%
## Corelation between selected variables- 2015 data

corr = filtered_col_df.corr().abs()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
fig.set_size_inches(20,8)
ticks = np.arange(0,len(filtered_col_df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(filtered_col_df.columns)
ax.set_yticklabels(filtered_col_df.columns)
plt.show()

# %%
#Co-relation on 2017 data

corr = data_corr.corr()
corr2 = corr[(corr >0.4) & (corr !=1)]
corr3 = corr2.dropna(thresh=1)
from matplotlib import pyplot
pyplot.figure(figsize=(25, 18))
sns.heatmap(corr3, cbar = True,   annot=True,  cmap= 'coolwarm')

# %%
## Variables with maximum corelation

max_corr_vars = (corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
                 .stack()
                 .sort_values(ascending=False))
print(max_corr_vars)
# Out:
# Term            AmorTerm          1.000000
# UPB             Amount            0.999676
# Front           Back              0.997739
# Income          IncRat            0.958424
# LocMedY         CurAreY           0.938265
# CoGender        CoBoCreditScor    0.923487
# CoRace          CoGender          0.910036
#                 CoBoCreditScor    0.885885
# CoAge           CoBoCreditScor    0.863801
# TraMedY         Tractrat          0.854177
# CoGender        CoAge             0.840467
# CoRace          CoAge             0.810239
# AmorTerm        Rate              0.547340
# Term            Rate              0.547340
# TraMedY         Amount            0.543980
#                 UPB               0.543571
# LocMedY         Amount            0.529412
#                 UPB               0.528931
# TraMedY         CurAreY           0.526395
# CurAreY         Amount            0.523725
#                 UPB               0.523262
# TraMedY         LocMedY           0.516077
# Income          UPB               0.478824
#                 Amount            0.478811
# LTV             PMI               0.430608
# Purpose         First             0.419641
# LTV             FedGuar           0.388906
# MSA             Tract             0.373797
# MinPer          Amount            0.354550
#                 UPB               0.354372
#                                     ...
# LTV             BoCreditScor     -0.197030
# IncRat          CoAge            -0.199235
# Income          CoAge            -0.203690
# IncRat          CoRace           -0.207055
# Income          CoBoCreditScor   -0.207644
# IncRat          CoBoCreditScor   -0.210391
# Income          CoRace           -0.210466
# CoAge           SpcHsgGoals      -0.212236
# MSA             CurAreY          -0.213124
#                 TraMedY          -0.213217
# CoRace          SpcHsgGoals      -0.215093
# IncRat          CoGender         -0.217264
# Income          CoGender         -0.217559
# CoGender        SpcHsgGoals      -0.224901
# MSA             AcqTyp           -0.230575
# CoBoCreditScor  SpcHsgGoals      -0.233584
# FedGuar         BoCreditScor     -0.247365
# Purpose         PMI              -0.255911
#                 AmorTerm         -0.262253
#                 Term             -0.262253
# LTV             BoAge            -0.263247
# FedGuar         First            -0.308237
# FeatureID       AcqTyp           -0.341513
# LTV             First            -0.351840
#                 Purpose          -0.433825
# Geog            AcqTyp           -0.475713
# NumBor          CoAge            -0.865754
#                 CoRace           -0.900670
#                 CoGender         -0.938432
#                 CoBoCreditScor   -0.948884
# Length: 861, dtype: float64

# %% [markdown]
# # Correlations:
# ##### Lets start with income amount and rate:

# %%
amount_rate_income = data[["Amount", "Rate", "Income" ]]

# %%
sns.pairplot(amount_rate_income.dropna())

# %%
amount_DTI_Income = data[['Amount', 'IncRat', 'Income']]

# %%
sns.pairplot(amount_DTI_Income.dropna())

# %%
pmt_rate_amount = filtered_col_df[['PMT','Rate','Amount']]

# %%
sns.pairplot(pmt_rate_amount.dropna())

# %%
creds_rate_amount = data[['BoCreditScor','Rate','Amount']]

# %%
sns.pairplot(creds_rate_amount.dropna())

# %% [markdown]
# ##### No strong correlations found here, need to to analyze it at indivisual level
#
# #### Lets Consider FICO

# %%
#2017 data

print("Average Interest Rate: ")
c1 = data[data["BoCreditScor"] ==1].describe()["Rate"]['mean']
c2 = data[data["BoCreditScor"] ==2].describe()["Rate"]['mean']
c3 = data[data["BoCreditScor"] ==3].describe()["Rate"]['mean']
c4 = data[data["BoCreditScor"] ==4].describe()["Rate"]['mean']
c5 = data[data["BoCreditScor"] ==5].describe()["Rate"]['mean']


print("1) CREDIT SCORE = <620 \nAverage interest rate =",c1,"\n\n2)CREDIT SCORE = 620 to < 660\nAverage interest rate =",c2," \n\n3) CREDIT SCORE = 660 < 700\nAverage interest rate = ",c3," \n\n4) CREDIT SCORE =700 < 760\nAverage interest rate = ",c4," \n\n5) CREDIT SCORE = 760\nAverage interest rate = ",c5)
print("\n\n\nPrime Interest Rates in 2017:\n12/14/2017 4.50%\n06/15/2017 4.25%\n03/16/2017 4.00%\n\n*Soucre: https://www.jpmorganchase.com/corporate/About-JPMC/historical-prime-rate.htm ")
print("\n\nGood the score, less the interest rate")
# Out:
# Average Interest Rate:
# 1) CREDIT SCORE = <620
# Average interest rate = 0.040911538461538464
#
# 2)CREDIT SCORE = 620 to < 660
# Average interest rate = 0.04045406582768636
#
# 3) CREDIT SCORE = 660 < 700
# Average interest rate =  0.04049320629660314
#
# 4) CREDIT SCORE =700 < 760
# Average interest rate =  0.039878112867833646
#
# 5) CREDIT SCORE = 760
# Average interest rate =  0.039161233774924094
#
#
#
# Prime Interest Rates in 2017:
# 12/14/2017 4.50%
# 06/15/2017 4.25%
# 03/16/2017 4.00%
#
# *Soucre: https://www.jpmorganchase.com/corporate/About-JPMC/historical-prime-rate.htm
#
#
# Good the score, less the interest rate

# %%
#2017 data

c1 = data[data["BoCreditScor"] == 1].describe()["LTV"]['mean']
c2 = data[data["BoCreditScor"] == 2].describe()["LTV"]['mean']
c3 = data[data["BoCreditScor"] == 3].describe()["LTV"]['mean']
c4 = data[data["BoCreditScor"] == 4].describe()["LTV"]['mean']
c5 = data[data["BoCreditScor"] == 5].describe()["LTV"]['mean']

print("1 = <620 \nAverage LTV =",c1,"\n\n2 = 620 to < 660\nAverage LTV =",c2," \n\n3 = 660 < 700\nAverage LTV = ",c3," \n\n4 =700 < 760\nAverage LTV = ",c4," \n\n5 = 760\nAverage LTV = ",c5)
print("\nHere people with more Credit score got higher amount of Loan\n\n\n")
# Out:
# 1 = <620
# Average LTV = 0.9463076923076914
#
# 2 = 620 to < 660
# Average LTV = 0.8534075508228454
#
# 3 = 660 < 700
# Average LTV =  0.8141971830986046
#
# 4 =700 < 760
# Average LTV =  0.7857367917627406
#
# 5 = 760
# Average LTV =  0.740714906998418
#
# Here people with more Credit score got higher amount of Loan

# %%
sns.jointplot('Rate','BoCreditScor',data,kind='scatter')

# %% [markdown]
# #### Lets try State wise interest rate

# %%
data_with_states = data.merge(state_df, how='left')
data_with_states =data_with_states.rename(columns = {"Name": "Property_State"})
data_with_states.head()
# Out:
#    Year  Assigned ID     Bank  FIPSStateCode  FIPSCountyCode    MSA  \
# 0  2017      2092102  Atlanta             72              15  25020
# 1  2017      2092103  Atlanta             66              10  99999
# 2  2017      2092104  Atlanta             66              10  99999
# 3  2017      2092105  Atlanta             48             439  19100
# 4  2017      2092106  Atlanta              6              99  33700
#
#     FeatureID    Tract  MinPer  TraMedY     ...       Corace4  Corace5  HOEPA  \
# 0     1609553  2802.02   99.15    15863     ...             6        6      2
# 1  9999999999  9540.00   92.90    75804     ...             6        6      2
# 2     1389637  9563.00   92.90    49250     ...             6        6      2
# 3     1337443  1141.03   25.31   102791     ...             6        6      2
# 4      277574    32.02   71.74    58235     ...             6        6      2
#
#    LienStatus  SpcHsgGoals  FedFinStbltyPlan  AcqTyp  GSEREO  Property_State  \
# 0           1            2                 2       1       2     Puerto Rico
# 1           1            2                 2       1       2            Guam
# 2           1            2                 2       1       2            Guam
# 3           1            2                 2       1       2           Texas
# 4           1            2                 2       1       2      California
#
#    Postal Code
# 0           PR
# 1           GU
# 2           GU
# 3           TX
# 4           CA
#
# [5 rows x 84 columns]

# %%
#2017 data

states = set(data_with_states["Property_State"])
clean_states = list(states)
clean_states.remove(clean_states[0])

# %%
rate_state={}
for bank in clean_states:
    rate = data_with_states[data_with_states["Property_State"] =="{0}".format(bank)].describe()["Rate"]['mean']
    rate_state[bank] = rate

# %%
rate_state_df = pd.DataFrame(list(rate_state.items()), columns=["State","Avg_Rate"])

# %%
#2017 data

rate_state_df
# Out:
#              State  Avg_Rate
# 0           Alaska  0.037517
# 1        Wisconsin  0.039213
# 2      Connecticut  0.038665
# 3       New Mexico  0.040428
# 4           Kansas  0.039103
# 5    West Virginia  0.040154
# 6         Michigan  0.039548
# 7         Virginia  0.040650
# 8    Massachusetts  0.039045
# 9          Vermont  0.039975
# 10     Mississippi  0.039140
# 11      California  0.041248
# 12         Arizona  0.040057
# 13        Colorado  0.039804
# 14         Montana  0.039152
# 15        Delaware  0.039093
# 16         Wyoming  0.039823
# 17         Alabama  0.039583
# 18    Rhode Island  0.040739
# 19    South Dakota  0.039037
# 20           Texas  0.040730
# 21       Louisiana  0.043029
# 22     Puerto Rico  0.035579
# 23         Florida  0.040654
# 24  North Carolina  0.039195
# 25      Washington  0.040787
# 26            Guam  0.035560
# 27        New York  0.039409
# 28            Ohio  0.038941
# 29        Oklahoma  0.039408
# 30            Utah  0.037578
# 31    Pennsylvania  0.041125
# 32          Hawaii  0.038859
# 33  South Carolina  0.038739
# 34        Kentucky  0.039313
# 35         Indiana  0.039305
# 36            Iowa  0.038604
# 37          Nevada  0.039563
# 38        Maryland  0.040611
# 39    North Dakota  0.039819
# 40        Missouri  0.039625
# 41       Tennessee  0.039399
# 42        Illinois  0.039402
# 43        Arkansas  0.040444
# 44           Maine  0.039929
# 45   New Hampshire  0.039638
# 46       Minnesota  0.038600
# 47           Idaho  0.040024
# 48         Georgia  0.040004
# 49        Nebraska  0.039850
# 50          Oregon  0.039529
# 51      New Jersey  0.039847

# %% [markdown]
# #### Lets try location wise (Federal Home Loan Bank District)

# %%
#2017 data

for bank in set(data["Bank"]):
    print("Average Interest Rate in :",bank)
    print(data[data["Bank"] =="{0}".format(bank)].describe()["Rate"]['mean'],"\n")
# Out:
# Average Interest Rate in : Chicago
# 0.039630017369335795
#
# Average Interest Rate in : Des Moines
# 0.03893721350187584
#
# Average Interest Rate in : New York
# 0.03952871287128691
#
# Average Interest Rate in : Pittsburgh
# 0.04161394998493644
#
# Average Interest Rate in : Cincinnati
# 0.03888262222222253
#
# Average Interest Rate in : Atlanta
# 0.036659400749063785
#
# Average Interest Rate in : San Francisco
# 0.04161605972323505
#
# Average Interest Rate in : Boston
# 0.03916183929116966
#
# Average Interest Rate in : Indianapolis
# 0.03942237391747393
#
# Average Interest Rate in : Dallas
# 0.042373804971320185
#
# Average Interest Rate in : Topeka
# 0.03935838196590042

# %%
# Sampling the data for visualization 
#******* 2015 data starts again ********#

sample_200 = filtered_col_df.sample(200)

# %%
#Plotting AmorTerm and Rate ---> Corr value = 0.78

sample_200.plot(x="AmorTerm", y="Rate", kind = "bar", figsize=(60,10))

# %%
#Using a pairplot
sns.pairplot(sample_200[['Rate', 'AmorTerm']])

# %% [markdown]
# Seems, higher the AmorTerm, higher the rate. Taking mean rate for different
# AmorTerms

# %%
sample_200['AmorTerm'].unique()
# Out:
# array([15, 30, 20, 29, 27])

# %%
print("Average Interest Rate: ")
c1 = filtered_col_df[filtered_col_df["AmorTerm"] ==15].describe()["Rate"]['mean']
c2 = filtered_col_df[filtered_col_df["AmorTerm"] ==30].describe()["Rate"]['mean']
c3 = filtered_col_df[filtered_col_df["AmorTerm"] ==20].describe()["Rate"]['mean']
c4 = filtered_col_df[filtered_col_df["AmorTerm"] ==29].describe()["Rate"]['mean']
c5 = filtered_col_df[filtered_col_df["AmorTerm"] ==27].describe()["Rate"]['mean']


print("1) AmorTerm = 15 \nAverage interest rate =",c1,"\n\n2)AmorTerm = 30\nAverage interest rate =",c2," \n\n3) AmorTerm = 20\nAverage interest rate = ",c3," \n\n4) AmorTerm =29\nAverage interest rate = ",c4," \n\n5) AmorTerm = 27\nAverage interest rate = ",c5)
print("\n\n\nPrime Interest Rates in 2017:\n12/14/2017 4.50%\n06/15/2017 4.25%\n03/16/2017 4.00%\n\n*Soucre: https://www.jpmorganchase.com/corporate/About-JPMC/historical-prime-rate.htm ")
print("\n\n We can strongly conclude the above assumption")
# Out:
# Average Interest Rate:
# 1) AmorTerm = 15
# Average interest rate = 0.031390153092467066
#
# 2)AmorTerm = 30
# Average interest rate = 0.038940242583664145
#
# 3) AmorTerm = 20
# Average interest rate =  0.03634135838150092
#
# 4) AmorTerm =29
# Average interest rate =  0.03985958702064882
#
# 5) AmorTerm = 27
# Average interest rate =  0.03739574468085106
#
#
#
# Prime Interest Rates in 2017:
# 12/14/2017 4.50%
# 06/15/2017 4.25%
# 03/16/2017 4.00%
#
# *Soucre: https://www.jpmorganchase.com/corporate/About-JPMC/historical-prime-rate.htm
#
#
#  We can strongly conclude the above assumption

# %% [markdown]
# # Income Vs PMT
#
# Looking at the pairplot, we can say the monthly payment is highly co-related to the total income of the borrower.

# %%
#Plotting PMT, Income and Rate ---> Corr value = 0.78

sample_200.plot(x="PMT", y='Income', kind = "bar", figsize=(80, 30))

# %%
sns.pairplot(sample_200[['Income','PMT']])

# %%
sns.pairplot(sample_200[['Income','Rate','PMT']])

# %% [markdown]
# # Let's track down how LTV affects the mortgage applications.

# %%
max_LTV_df = sample_200.sort_values('LTV', ascending=False)

# %%
min_LTV_df = filtered_col_df.sort_values('LTV', ascending=True)

# %%
max_LTV_df.head(10)
# Out:
#        Year  AssignedID       FHLBank  FIPSStateCode  FIPSCountyCode  Income  \
# 4717   2015     1986070       Chicago             17              77   43500
# 3119   2015     1961673       Chicago             17              21   47840
# 3901   2015     1962455       Chicago             39              63   99108
# 46259  2015     1994080        Topeka              8              41   87720
# 32371  2015     1999821  Indianapolis             18              39   62328
# 47231  2015     1995052        Topeka              8              41  216744
# 21074  2015     1952318    Des Moines             19              91  146983
# 23811  2015     1974472  Indianapolis             26             161   90470
# 5695   2015     1962964    Cincinnati             39              57   60000
# 1222   2015     1958564        Boston             23              13  193247
#
#        CurAreY  IncRat     UPB   LTV   ...     Occup    Rate  Amount   Front  \
# 4717     57400  0.7578   42000  1.05   ...         1  0.0438   42000  0.1152
# 3119     57400  0.8334   56122  1.00   ...         1  0.0375   56122  0.1036
# 3901     53600  1.8490  101234  1.00   ...         1  0.0388  101234  0.0763
# 46259    73400  1.1951  403000  1.00   ...         1  0.0363  403000  0.2880
# 32371    53300  1.1694  114782  0.99   ...         1  0.0425  114782  0.1700
# 47231    73400  2.9529  235653  0.97   ...         1  0.0363  235653  0.1613
# 21074    59300  2.4786  213442  0.95   ...         1  0.0400  213750  0.1311
# 23811    87400  1.0351  166250  0.95   ...         1  0.0400  166250  0.1100
# 5695     60500  0.9917  161500  0.95   ...         1  0.0400  161500  0.2400
# 1222     54900  3.5200  254600  0.95   ...         1  0.0388  254600  0.1222
#
#          Back  BoCreditScor  CoCreditScor  PMI  PropertyLocation      PMT
# 4717   0.3334             3             9  0.0          Illinois  2542.16
# 3119   0.3557             4             9  0.0          Illinois  3147.75
# 3901   0.1611             4             3  0.0              Ohio  5769.37
# 46259  0.5191             5             5  0.0          Colorado    22270
# 32371  0.2100             2             9  0.0           Indiana  6840.81
# 47231  0.5468             3             2  0.0          Colorado  13022.3
# 21074  0.2879             3             3  0.3              Iowa  12361.2
# 23811  0.3100             5             4  0.3          Michigan  9614.25
# 5695   0.2800             5             9  0.3              Ohio  9339.56
# 1222   0.2908             3             3  0.3             Maine  14509.8
#
# [10 rows x 32 columns]

# %%
min_ltv_sample = min_LTV_df.sample(50)
min_ltv_sample.plot(x='Rate', y=['Income', 'Amount'], figsize=(80,40), kind = "bar")
# Out:
# /Users/ujwal/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
min_ltv_sample.plot(x="LTV", y="Rate", kind="bar", figsize=(60,20))

# %%
max_ltv_sample = max_LTV_df.sample(50)
max_ltv_sample.plot(x='Rate', y=['Income', 'Amount'], figsize=(80,40), kind = "bar")
# Out:
# /Users/ujwal/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
max_ltv_sample.plot(x="LTV", y="Rate", kind="bar", figsize=(60,20))

# %% [markdown]
# # No concrete evidence that proves higher LTV causes higher interest rate
#
# Taking mean rate on max and min LTV dataFrames

# %%
print("Average Interest rates for LTV")

c1 = filtered_col_df[filtered_col_df['LTV']<=0.78].describe()["Rate"]['mean']
c2 = filtered_col_df[filtered_col_df['LTV']>=0.80].describe()["Rate"]['mean']
print("1) \nAverage interest rate for Min LTV=",c1,"\n\n2)\nAverage interest rate for Max LTV =",c2)
# Out:
# Average Interest rates for LTV
# 1)
# Average interest rate for Min LTV= 0.03621318966695637
#
# 2)
# Average interest rate for Max LTv = 0.03833454537984415

# %% [markdown]
# Interest Rate goes high if the LTV is greater than 80%

# %% [markdown]
# # Considering all the pre-processing, we can define range of thresholds.
#
# IDEA:
#
# 1) Define minimum band which the application should lie under
# 2) Create a baseline machine learning model and train the model with respect to these range of values
# 3) Test the model whether it approves an application if it lies under all /most of the thresholds
