# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
from pylab import rcParams

# %% [markdown]
# #  Loading the Data

# %%
data = pd.read_csv(r"C:\Users\Jennifer\Desktop\CS691\2017_PUDB.csv")

# %%
df =pd.DataFrame(data)

# %%
data.columns
# Out:
# Index([u'Year', u'Assigned ID', u'Bank', u'FIPSStateCode', u'FIPSCountyCode',
#        u'MSA', u'FeatureID', u'Tract', u'MinPer', u'TraMedY', u'LocMedY',
#        u'Tractrat', u'Income', u'CurAreY', u'IncRat', u'UPB', u'LTV',
#        u'MortDate', u'AcquDate', u'Purpose', u'Coop', u'Product', u'FedGuar',
#        u'Term', u'AmorTerm', u'SellType', u'NumBor', u'First', u'CICA',
#        u'BoRace', u'CoRace', u'BoGender', u'CoGender', u'BoAge', u'CoAge',
#        u'Occup', u'NumUnits', u'Bed1', u'Bed2', u'Bed3', u'Bed4', u'Aff1',
#        u'Aff2', u'Aff3', u'Aff4', u'Rent1', u'Rent2', u'Rent3', u'Rent4',
#        u'RentUt1', u'RentUt2', u'RentUt3', u'RentUt4', u'Geog', u'Rate',
#        u'Amount', u'Front', u'Back', u'BoCreditScor', u'CoBoCreditScor',
#        u'PMI', u'Self', u'PropType', u'ArmIndex', u'ArmMarg', u'PrepayP',
#        u'BoEth', u'Race2', u'Race3', u'Race4', u'Race5', u'CoEth', u'Corace2',
#        u'Corace3', u'Corace4', u'Corace5', u'HOEPA', u'LienStatus',
# ...

# %%
data.describe()
# Out:
#           Year   Assigned ID  FIPSStateCode  FIPSCountyCode           MSA  \
# count  55990.0  5.599000e+04   55990.000000    55990.000000  55990.000000
# mean    2017.0  2.100277e+06      27.259832       81.132470  35921.761654
# std        0.0  1.616339e+04      13.833729       68.953152  23564.415009
# min     2017.0  2.072282e+06       1.000000        1.000000  10100.000000
# 25%     2017.0  2.086280e+06      18.000000       31.000000  19380.000000
# 50%     2017.0  2.100278e+06      25.000000       67.000000  30460.000000
# 75%     2017.0  2.114275e+06      39.000000      115.000000  41860.000000
# max     2017.0  2.128272e+06      72.000000      840.000000  99999.000000
#
#           FeatureID         Tract        MinPer        TraMedY        LocMedY  \
# count  5.599000e+04  55990.000000  55990.000000   55990.000000   55990.000000
# mean   4.546789e+09   2864.767451     18.440787   82372.062333   69385.696642
# ...

# %%
data1 = data.head(100)
from IPython.core.display import display, HTML
display(HTML(data1.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Assigned ID</th>
#       <th>Bank</th>
#       <th>FIPSStateCode</th>
#       <th>FIPSCountyCode</th>
#       <th>MSA</th>
#       <th>FeatureID</th>
#       <th>Tract</th>
#       <th>MinPer</th>
#       <th>TraMedY</th>
#       <th>LocMedY</th>
#       <th>Tractrat</th>
#       <th>Income</th>
#       <th>CurAreY</th>
#       <th>IncRat</th>
#       <th>UPB</th>
#       <th>LTV</th>
#       <th>MortDate</th>
#       <th>AcquDate</th>
#       <th>Purpose</th>
#       <th>Coop</th>
#       <th>Product</th>
#       <th>FedGuar</th>
#       <th>Term</th>
#       <th>AmorTerm</th>
#       <th>SellType</th>
#       <th>NumBor</th>
#       <th>First</th>
#       <th>CICA</th>
#       <th>BoRace</th>
#       <th>CoRace</th>
#       <th>BoGender</th>
#       <th>CoGender</th>
#       <th>BoAge</th>
#       <th>CoAge</th>
#       <th>Occup</th>
# ...

# %% [markdown]
# # Field Correlation

# %%
interested_col_list = ['Year', 'AssignedID', 'FHLBank', 'FIPSStateCode', 'FIPSCountyCode',
       'MSA', 'FeatureID', 'Tract', 'MinPer', 'TraMedY', 'LocMedY', 'Tractrat',
       'Income', 'CurAreY', 'IncRat', 'UPB', 'LTV', 'MortDate', 'AcqDate',
       'Purpose', 'Coop', 'Product', 'FedGuar', 'Term', 'AmorTerm', 'SellType',
       'NumBor', 'First', 'CICA', 'Rate', 'Amount']

# %%
filtered_col_df = data[interested_col_list]
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-56-03c4db41a5f9> in <module>()
# ----> 1 filtered_col_df = data[interested_col_list]
#
# C:\Users\Jennifer\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# C:\Users\Jennifer\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# C:\Users\Jennifer\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
# ...

# %%
max_LTV_df = filtered_col_df.sort_values('LTV', ascending=False)
max_LTV_df = filtered_col_df.sort_values('LTV', ascending=False)
min_LTV_head_df.plot(x='LTV', y='Rate', kind="bar")
min_LTV_head_df.plot(x='LTV', y='Rate', kind="bar")
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-54-b883b3c41038> in <module>()
# ----> 1 max_LTV_df = filtered_col_df.sort_values('LTV', ascending=False)
#       2 max_LTV_df = filtered_col_df.sort_values('LTV', ascending=False)
#       3 min_LTV_head_df.plot(x='LTV', y='Rate', kind="bar")
#       4 min_LTV_head_df.plot(x='LTV', y='Rate', kind="bar")
#
# NameError: name 'filtered_col_df' is not defined

# %%
corr = min_LTV_df.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(min_LTV_df.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(min_LTV_df.columns)
ax.set_yticklabels(min_LTV_df.columns)
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-50-9117c7f0bed5> in <module>()
# ----> 1 corr = min_LTV_df.corr()
#       2 fig = plt.figure()
#       3 ax = fig.add_subplot(111)
#       4 cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
#       5 fig.colorbar(cax)
#
# NameError: name 'min_LTV_df' is not defined

# %%
display(HTML(data.corr().to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Assigned ID</th>
#       <th>FIPSStateCode</th>
#       <th>FIPSCountyCode</th>
#       <th>MSA</th>
#       <th>FeatureID</th>
#       <th>Tract</th>
#       <th>MinPer</th>
#       <th>TraMedY</th>
#       <th>LocMedY</th>
#       <th>Tractrat</th>
#       <th>Income</th>
#       <th>CurAreY</th>
#       <th>IncRat</th>
#       <th>UPB</th>
#       <th>LTV</th>
#       <th>MortDate</th>
#       <th>AcquDate</th>
#       <th>Purpose</th>
#       <th>Coop</th>
#       <th>Product</th>
#       <th>FedGuar</th>
#       <th>Term</th>
#       <th>AmorTerm</th>
#       <th>SellType</th>
#       <th>NumBor</th>
#       <th>First</th>
#       <th>CICA</th>
#       <th>BoRace</th>
#       <th>CoRace</th>
#       <th>BoGender</th>
#       <th>CoGender</th>
#       <th>BoAge</th>
#       <th>CoAge</th>
#       <th>Occup</th>
#       <th>NumUnits</th>
# ...

# %%
sns.jointplot('IncRat','Income',data,kind='scatter')
# Out:
# C:\Users\Jennifer\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Jennifer\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot('Rate','BoCreditScor',data,kind='scatter')
# Out:
# C:\Users\Jennifer\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Jennifer\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # STATE BREAKDOWN:

# %%
meanIncomePerState=df.groupby('FIPSStateCode')[['Income']].mean()
meanIncomePerState
# Out:
#                       Income
# FIPSStateCode
# 1              121603.904762
# 2              128562.000000
# 4              122863.223684
# 5              119740.050000
# 6              155881.278404
# 8              103096.656445
# 9              110132.788906
# 10             138228.785714
# 11             175373.795775
# 12             120667.154657
# 13             121707.925831
# 15             112297.764706
# 16              88320.073171
# 17              88725.723077
# 18              98549.078574
# 19              88461.817017
# 20              96322.374175
# 21              99690.732886
# 22             111376.729282
# 23             113898.980676
# 24             149581.069307
# 25             119856.871359
# 26             109820.773688
# 27             106827.386620
# 28             123543.900000
# 29              96926.305283
# 30             102018.804348
# 31             101144.730411
# 32             107830.203540
# 33             119995.058252
# ...

# %%
# in respect to Credit score 
df.groupby('FIPSStateCode')[['Amount', 'Income', 'Rate','IncRat','BoCreditScor']].mean()
# Out:
#                       Amount         Income      Rate    IncRat  BoCreditScor
# FIPSStateCode
# 1              250234.714286  121603.904762  0.039583  2.043419      4.253968
# 2              262640.333333  128562.000000  0.037517  1.469600      4.833333
# 4              245128.894737  122863.223684  0.040057  2.009216      4.375000
# 5              226661.164286  119740.050000  0.040444  2.076828      4.114286
# 6              483663.332864  155881.278404  0.041248  2.006036      4.411737
# 8              265283.722453  103096.656445  0.039804  1.402511      4.147609
# 9              239043.513097  110132.788906  0.038665  1.233971      4.064715
# 10             291520.964286  138228.785714  0.039093  1.998643      4.357143
# 11             531187.330986  175373.795775  0.041427  1.604849      4.521127
# 12             254879.762742  120667.154657  0.040654  1.998718      4.147627
# 13             273490.061381  121707.925831  0.040004  1.804416      4.306905
# ...

# %%
# num of aquiries in 20 most frequent cities 
df['FIPSStateCode'].value_counts()[:20].plot(kind='barh')

# %%
plt.figure(figsize=(15,8))
count = df['Bank'].value_counts()
sns.barplot(count.values, count.index)
for i, v in enumerate(count.values):
    plt.text(0.8,i,v,color='k',fontsize=19)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Cities', fontsize=12)
plt.title("Count", fontsize=16)
# Out:
# Text(0.5,1,'Count')

# %% [markdown]
# # CREDIT SCORE IMPACT ON RATE

# %%
data[data["BoCreditScor"] ==1].describe()["Rate"]
# Out:
# count    130.000000
# mean       0.040912
# std        0.003439
# min        0.032500
# 25%        0.037500
# 50%        0.041300
# 75%        0.043800
# max        0.047500
# Name: Rate, dtype: float64

# %%
ax = sns.lineplot(x="Rate", y="Income", data=df)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-48-8b3b9f09f3e0> in <module>()
# ----> 1 ax = sns.lineplot(x="Rate", y="Income", data=df)
#
# AttributeError: 'module' object has no attribute 'lineplot'

# %%
data[data["BoCreditScor"] ==2].describe()["Rate"]
# Out:
# count    2066.000000
# mean        0.040454
# std         0.003593
# min         0.027500
# 25%         0.037500
# 50%         0.040000
# 75%         0.042500
# max         0.051300
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==3].describe()["Rate"]
# Out:
# count    6035.000000
# mean        0.040493
# std         0.003369
# min         0.027500
# 25%         0.038800
# 50%         0.040000
# 75%         0.042500
# max         0.050000
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==4].describe()["Rate"]
# Out:
# count    17773.000000
# mean         0.039878
# std          0.002994
# min          0.026300
# 25%          0.038800
# 50%          0.040000
# 75%          0.041300
# max          0.051300
# Name: Rate, dtype: float64

# %%
data[data["BoCreditScor"] ==5].describe()["Rate"]
# Out:
# count    29892.000000
# mean         0.039161
# std          0.002899
# min          0.025000
# 25%          0.037500
# 50%          0.039900
# 75%          0.041300
# max          0.050000
# Name: Rate, dtype: float64

# %%
print("Average Interest Rate: ")
c1 = data[data["BoCreditScor"] ==1].describe()["Rate"]['mean']
c2 = data[data["BoCreditScor"] ==2].describe()["Rate"]['mean']
c3 = data[data["BoCreditScor"] ==3].describe()["Rate"]['mean']
c4 = data[data["BoCreditScor"] ==4].describe()["Rate"]['mean']
c5 = data[data["BoCreditScor"] ==5].describe()["Rate"]['mean']

print("1 = <620 \n Average LTV =",c1,"\n\n2 = 620 to < 660\nAverage LTV =",c2," \n\n3 = 660 < 700\nAverage LTV = ",c3," \n\n4 =700 < 760\nAverage LTV = ",c4," \n\n5 = 760\nAverage LTV = ",c5)
# Out:
# Average Interest Rate:
# ('1 = <620 \n Average LTV =', 0.040911538461538464, '\n\n2 = 620 to < 660\nAverage LTV =', 0.04045406582768636, ' \n\n3 = 660 < 700\nAverage LTV = ', 0.04049320629660314, ' \n\n4 =700 < 760\nAverage LTV = ', 0.039878112867833646, ' \n\n5 = 760\nAverage LTV = ', 0.039161233774924094)

# %% [markdown]
# # CREDIT PROFILE

# %%
# a feamale with loan amount $400000 profile 
df[(df['Amount']== 400000) & (df['BoGender']==2 )].max()
# Out:
# Year                      2017
# Assigned ID            2127618
# Bank                    Topeka
# FIPSStateCode               55
# FIPSCountyCode             510
# MSA                      99999
# FeatureID           9999999999
# Tract                     9532
# MinPer                   72.54
# TraMedY                 201154
# LocMedY                 108996
# Tractrat                 2.707
# Income                  397275
# CurAreY                 113000
# IncRat                  5.9831
# UPB                     400000
# LTV                          1
# MortDate                  2017
# AcquDate                  2017
# Purpose                      2
# Coop                         2
# Product                      1
# FedGuar                      2
# Term                       360
# AmorTerm                   360
# SellType                     1
# NumBor                       2
# First                        2
# CICA                         9
# BoRace                       7
# ...

# %%
# number of aplicants per age ( only 20 most frequent )
df['BoAge'].value_counts()[:20].plot(kind='barh')
